# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
parameter = np.linspace(0, 10, 1000) #dt = 0,01
r = 5
omega = 2
v_r = 0
x = [(r-dt*v_r)*np.cos(dt*omega) for dt in parameter]
y = [(r-dt*v_r)*np.sin(dt*omega) for dt in parameter]

# %%
plt.figure(figsize=(4,4), dpi= 150)
plt.plot(x,y)

# %%
parameter = np.linspace(0, 10, 1000) #dt = 0,01
r = 5
omega = 2*np.pi
v_r = 1000
x = [(r-dt*v_r)*np.cos(dt*omega) for dt in parameter]
y = [(r-dt*v_r)*np.sin(dt*omega) for dt in parameter]

# %%
plt.figure(figsize=(3,3), dpi= 150)
plt.plot(x,y)

# %%
parameter = np.linspace(0, 10, 1000) #dt = 0,01
a = 1
b = 8
omega = 1
v_r = 100
x = [b*np.cos(dt*omega) for dt in parameter]
y = [a*np.sin(dt*omega) for dt in parameter]

# %%
#plt.figure(figsize=(3,3), dpi= 150)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt

r = 5
T = 1
omega = 2*np.pi/T
dt = T/1000
v_r = r/T
t = np.arange(0,T+dt,dt)
x =(r-v_r*t)*np.cos(omega*t)
y = (r-v_r*t)*np.sin(omega*t)
fig, ax1= plt.subplots(figsize=(5,5))
ax1.plot(x,y)
ax1.set_xlabel("X osa")
ax1.set_ylabel("Y osa")
# Out:
# Text(0, 0.5, 'Y osa')

# %% [markdown]
# # Úloha 3

# %%
import numpy as np
import matplotlib.pyplot as plt

r = 5
T = 1
omega = 2*np.pi/T
omega = 2
dt = T/1000
v_r = r/T
t = np.arange(0,T+dt,dt)
x =(r+r*np.sin(2*omega*t))*np.cos(omega*t)
y = (r+r*np.sin(2*omega*t))*np.sin(omega*t)
fig, ax1= plt.subplots(figsize=(5,5))
ax1.plot(x,y)
ax1.set_xlabel("X osa")
ax1.set_ylabel("Y osa")
# Out:
# Text(0, 0.5, 'Y osa')

# %%
import scipy
r = 10
T = 1
omega = 2*np.pi/T
dt = T/1000
vr = r/T
t = np.arange(0,2*T+dt,dt)
x =(r-vr*t)*np.cos(omega*t)
y = (r-vr*t)*np.sin(omega*t)

v_x = -vr*np.cos(omega*t) - r*(vr*t)*omega*np.sin(omega*t)
v_y = -vr*np.sin(omega*t)+ r*(vr*t)*omega*np.cos(omega*t)

v = np.sqrt(v_x**2+v_y**2)
s=0

for i in range(np.size(t)):
    s+=v[i]*dt
    
print("Dráha je",s,"m")

#v_xnum = [(x[int(dtt/t[1])]-x[int(dtt/t[1])-1])/dtt for dtt in t]

fig, ax1= plt.subplots(figsize=(5,5))
ax1.plot(t,v)
ax1.set_xlabel("X osa")
ax1.set_ylabel("Y osa")
# Out:
# Dráha je 1257.7500468943356 m
# Text(0, 0.5, 'Y osa')

# %%
plt.figure()
plt.plot(t,y, color="b",label="y(t)")
plt.plot(t,x,color="r", label="x(t)")
plt.legend()
plt.savefig("xt,yt dep",dpi=150)

# %%
v = omega*r
x = t*v -r*np.sin(v/r*t)  # sudá funkce, čili r*np.cos(-omega*t) = r*np.cos(omega*t) r*np.cos(omega*(t+np.pi/2) = -r*np.cos(omega*(t+np.pi/2)
y = r -r*np.cos(v/r*(t)) # t -> t+T/4
v_x = v - v*(1-cos(v*t/r))
v_y = v*(sin(v*t/r))

# %%
plt.plot(t,v_x)
plt.plot(t,v_y)

# %%
plt.plot(x,y)

# %%
v2 = np.sqrt(v_x**2 + v_y**2)
plt.plot(t,v2)

# %% [markdown]
# ## Domácí úkol
